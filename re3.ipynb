# %%
# !git clone https://github.com/dpu-oktant/Re3_PyCharm.git
# Out:
# Cloning into 'Re3_PyCharm'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 110 (delta 28), reused 85 (delta 13), pack-reused 0
# Receiving objects: 100% (110/110), 26.41 MiB | 11.83 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
# !pip3 install cvzone
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26297 sha256=d16e2109ba92f6e140ff0c49e34e48e7dbcc4af810c76e55861ed5a69d69152a
#   Stored in directory: /root/.cache/pip/wheels/2c/9f/b3/92e945ac4a71bf727a92463f38155cc5a4fa49c5010b38ec4c
# Successfully built cvzone
# ...

# %%
# !pip3 install torch torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 61.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.0 MB/s eta 0:00:00
# ...

# %%
# %cd Re3_PyCharm/demo
# Out:
# /content/Re3_PyCharm/demo

# %%
# !pip3 install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 16.6 MB/s eta 0:00:00
# ...

# %%
# !python yolo_demo_13.py
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# 0: 384x640 1 uav, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Coordinates: 364, 186, 476, 247
#
# 0: 384x640 1 uav, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Coordinates: 362, 186, 476, 247
#
# 0: 384x640 1 uav, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Coordinates: 361, 185, 475, 247
#
# 0: 384x640 1 uav, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Coordinates: 358, 184, 475, 248
#
# 0: 384x640 1 uav, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Coordinates: 353, 182, 474, 248
#
# 0: 384x640 1 uav, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ...
